# %% [markdown]
# # cProfiler

# %%
import cProfile

# %%
help(cProfile)
# Out:
# Help on module cProfile:
#
# NAME
#     cProfile
#
# MODULE REFERENCE
#     https://docs.python.org/3.12/library/cprofile.html
#
#     The following documentation is automatically generated from the Python
#     source files.  It may be incomplete, incorrect or include features that
#     are considered implementation detail and may vary between Python
#     implementations.  When in doubt, consult the module reference at the
#     location listed above.
#
# DESCRIPTION
#     Python interface for the 'lsprof' profiler.
#     Compatible with the 'profile' module.
#
# CLASSES
#     _lsprof.Profiler(builtins.object)
#         Profile
#
#     class Profile(_lsprof.Profiler)
#      |  Profile(timer=None, timeunit=None, subcalls=True, builtins=True)
#      |
#      |  Builds a profiler object using the specified timer function.
#      |  The default timer is a fast built-in one based on real time.
#      |  For custom timer functions returning integers, timeunit can
#      |  be a float specifying a scale (i.e. how long each integer unit
#      |  is, in seconds).
#      |
#      |  Method resolution order:
#      |      Profile
#      |      _lsprof.Profiler
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __enter__(self)
#      |
#      |  __exit__(self, *exc_info)
#      |
#      |  create_stats(self)
#      |
#      |  dump_stats(self, file)
#      |
#      |  print_stats(self, sort=-1)
#      |
#      |  run(self, cmd)
#      |
#      |  runcall(self, func, /, *args, **kw)
#      |      # This method is more useful to profile a single function call.
#      |
#      |  runctx(self, cmd, globals, locals)
#      |
#      |  snapshot_stats(self)
#      |
#      |  ----------------------------------------------------------------------
#      |  Data descriptors defined here:
#      |
#      |  __dict__
#      |      dictionary for instance variables
#      |
#      |  __weakref__
#      |      list of weak references to the object
#      |
#      |  ----------------------------------------------------------------------
#      |  Methods inherited from _lsprof.Profiler:
#      |
#      |  __init__(self, /, *args, **kwargs)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  clear(...)
#      |      clear()
#      |
#      |      Clear all profiling information collected so far.
#      |
#      |  disable(...)
#      |      disable()
#      |
#      |      Stop collecting profiling information.
#      |
#      |  enable(...)
#      |      enable(subcalls=True, builtins=True)
#      |
#      |      Start collecting profiling information.
#      |      If 'subcalls' is True, also records for each function
#      |      statistics separated according to its current caller.
#      |      If 'builtins' is True, records the time spent in
#      |      built-in functions separately from their caller.
#      |
#      |  getstats(self, /)
#      |      list of profiler_entry objects.
#      |
#      |      getstats() -> list of profiler_entry objects
#      |
#      |      Return all information collected by the profiler.
#      |      Each profiler_entry is a tuple-like object with the
#      |      following attributes:
#      |
#      |          code          code object
#      |          callcount     how many times this was called
#      |          reccallcount  how many times called recursively
#      |          totaltime     total time in this entry
#      |          inlinetime    inline time in this entry (not in subcalls)
#      |          calls         details of the calls
#      |
#      |      The calls attribute is either None or a list of
#      |      profiler_subentry objects:
#      |
#      |          code          called code object
#      |          callcount     how many times this is called
#      |          reccallcount  how many times this is called recursively
#      |          totaltime     total time spent in this call
#      |          inlinetime    inline time (not in further subcalls)
#
# FUNCTIONS
#     run(statement, filename=None, sort=-1)
#         Run statement under profiler optionally saving results in filename
#
#         This function takes a single argument that can be passed to the
#         "exec" statement, and an optional file name.  In all cases this
#         routine attempts to "exec" its first argument and gather profiling
#         statistics from the execution. If no file name is present, then this
#         function automatically prints a simple profiling report, sorted by the
#         standard name string (file/line/function-name) that is presented in
#         each line.
#
#     runctx(statement, globals, locals, filename=None, sort=-1)
#         Run statement under profiler, supplying your own globals and locals,
#         optionally saving results in filename.
#
#         statement and filename have the same semantics as profile.run
#
# DATA
#     __all__ = ['run', 'runctx', 'Profile']
#
# FILE
#     /usr/local/python/3.12.1/lib/python3.12/cProfile.py

# %%
dir(cProfile)
# Out:
# ['Profile',
#  '__all__',
#  '__builtins__',
#  '__cached__',
#  '__doc__',
#  '__file__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_lsprof',
#  '_pyprofile',
#  'importlib',
#  'io',
#  'label',
#  'main',
#  'run',
#  'runctx']

# %%
exec("20+10")

# %%
eval("20+10")
# Out:
# 30

# %%
cProfile.run("20+10")
# Out:
#          3 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %% [markdown]
# ncalls : Shows the number of calls made
#
# tottime: Total time taken by the given function. Note that the time made in calls to sub-functions are excluded.
#
# percall: Total time / No of calls. ( remainder is left out )
#
# cumtime: Unlike tottime, this includes time spent in this and all subfunctions that the higher-level function calls. It is most useful and is accurate for recursive functions.
#
# The percall following cumtime is calculated as the quotient of cumtime divided by primitive calls. The primitive calls include all the calls that were not included through recursion.

# %%
cProfile.run(
    """
result = []
for i in range(9):
    result.append(i)
"""
)
# Out:
#          12 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         9    0.000    0.000    0.000    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
cProfile.run(
    """
result = [i for i in range(9)]
"""
)
# Out:
#          3 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
cProfile.run(
    """
result = list(range(9))
""",
    filename=None,
    sort=-1,
)
# Out:
#          3 function calls in 0.000 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    0.000    0.000 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
# Code containing multiple functions
def create_array():
    arr = []
    for i in range(0, 400000):
        arr.append(i)


def print_statement():
    print("Array created successfully")


def main():
    create_array()
    print_statement()


cProfile.run("main()")
# Out:
# Array created successfully
#          400623 function calls (400615 primitive calls) in 0.109 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.003    0.003    0.094    0.094 1140210951.py:12(main)
#         1    0.052    0.052    0.091    0.091 1140210951.py:2(create_array)
#         1    0.000    0.000    0.000    0.000 1140210951.py:8(print_statement)
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#       2/1    0.004    0.002    0.094    0.094 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 _base.py:337(_invoke_callbacks)
#         1    0.000    0.000    0.000    0.000 _base.py:537(set_result)
#         1    0.000    0.000    0.001    0.001 asyncio.py:200(_handle_events)
#         1    0.000    0.000    0.000    0.000 asyncio.py:225(add_callback)
#         5    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#         5    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#         2    0.000    0.000    0.000    0.000 base_events.py:1879(_add_callback)
#         4    0.000    0.000    0.104    0.026 base_events.py:1894(_run_once)
#         5    0.000    0.000    0.000    0.000 base_events.py:1989(get_debug)
#         3    0.000    0.000    0.000    0.000 base_events.py:537(_check_closed)
#         1    0.000    0.000    0.000    0.000 base_events.py:717(is_closed)
#         5    0.000    0.000    0.000    0.000 base_events.py:731(time)
#         2    0.000    0.000    0.000    0.000 base_events.py:782(call_soon)
#         3    0.000    0.000    0.000    0.000 base_events.py:811(_call_soon)
#         1    0.000    0.000    0.000    0.000 base_events.py:835(call_soon_threadsafe)
#         1    0.000    0.000    0.000    0.000 concurrent.py:182(future_set_result_unless_cancelled)
#         1    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#         1    0.000    0.000    0.009    0.009 decorator.py:229(fun)
#        31    0.000    0.000    0.000    0.000 enum.py:1116(__new__)
#        16    0.000    0.000    0.000    0.000 enum.py:1531(__or__)
#         8    0.000    0.000    0.000    0.000 enum.py:1541(__and__)
#        31    0.000    0.000    0.000    0.000 enum.py:713(__call__)
#         3    0.000    0.000    0.000    0.000 events.py:32(__init__)
#         5    0.000    0.000    0.002    0.000 events.py:82(_run)
#         1    0.000    0.000    0.000    0.000 futures.py:394(_call_set_state)
#         1    0.000    0.000    0.009    0.009 history.py:55(only_when_enabled)
#         1    0.000    0.000    0.008    0.008 history.py:833(_writeout_input_cache)
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#         1    0.000    0.000    0.008    0.008 history.py:845(writeout_cache)
#         4    0.000    0.000    0.000    0.000 inspect.py:2782(name)
#        10    0.000    0.000    0.000    0.000 inspect.py:2794(kind)
#         1    0.000    0.000    0.000    0.000 inspect.py:2874(__init__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2882(args)
#         1    0.000    0.000    0.000    0.000 inspect.py:2905(kwargs)
#         1    0.000    0.000    0.000    0.000 inspect.py:2935(apply_defaults)
#         4    0.000    0.000    0.000    0.000 inspect.py:3075(parameters)
#         1    0.000    0.000    0.000    0.000 inspect.py:3119(_bind)
#         1    0.000    0.000    0.000    0.000 inspect.py:3254(bind)
#         2    0.000    0.000    0.000    0.000 ioloop.py:742(_run_callback)
#         1    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#         2    0.000    0.000    0.001    0.000 iostream.py:157(_handle_event)
#         2    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         2    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         1    0.000    0.000    0.000    0.000 iostream.py:259(schedule)
#         2    0.000    0.000    0.001    0.000 iostream.py:276(<lambda>)
#         2    0.000    0.000    0.001    0.000 iostream.py:278(_really_send)
#         2    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#         2    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:577(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 iostream.py:655(write)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:302(poll_control_queue)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:324(_flush)
#         1    0.000    0.000    0.000    0.000 locks.py:224(clear)
#         1    0.000    0.000    0.000    0.000 poll.py:31(register)
#         1    0.000    0.000    0.000    0.000 poll.py:80(poll)
#         4    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         4    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         1    0.000    0.000    0.000    0.000 queues.py:177(empty)
#         1    0.000    0.000    0.000    0.000 queues.py:186(put)
#         1    0.000    0.000    0.000    0.000 queues.py:209(put_nowait)
#         1    0.000    0.000    0.000    0.000 queues.py:225(get)
#         1    0.000    0.000    0.000    0.000 queues.py:256(get_nowait)
#         1    0.000    0.000    0.000    0.000 queues.py:309(_get)
#         1    0.000    0.000    0.000    0.000 queues.py:312(_put)
#         1    0.000    0.000    0.000    0.000 queues.py:317(__put_internal)
#         2    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 selector_events.py:129(_read_from_self)
#         1    0.000    0.000    0.000    0.000 selector_events.py:141(_write_to_self)
#         4    0.000    0.000    0.000    0.000 selector_events.py:746(_process_events)
#         2    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         3    0.000    0.000    0.000    0.000 selectors.py:451(select)
#        15    0.001    0.000    0.001    0.000 socket.py:626(send)
#         2    0.000    0.000    0.001    0.000 socket.py:703(send_multipart)
#         2    0.000    0.000    0.000    0.000 socket.py:774(recv_multipart)
#         1    0.000    0.000    0.000    0.000 threading.py:1153(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:1220(is_alive)
#         3    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         3    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         1    0.000    0.000    0.000    0.000 threading.py:394(notify)
#         1    0.000    0.000    0.000    0.000 threading.py:424(notify_all)
#         1    0.000    0.000    0.000    0.000 threading.py:601(is_set)
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         8    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         8    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         2    0.000    0.000    0.000    0.000 typing.py:1175(__instancecheck__)
#         4    0.000    0.000    0.000    0.000 typing.py:1239(__hash__)
#         2    0.000    0.000    0.000    0.000 typing.py:1446(__subclasscheck__)
#        28    0.000    0.000    0.000    0.000 typing.py:2119(cast)
#         6    0.000    0.000    0.000    0.000 typing.py:378(inner)
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 unix_events.py:81(_process_self_data)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:427(flush)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:468(update_flag)
#         5    0.000    0.000    0.000    0.000 zmqstream.py:538(receiving)
#         4    0.000    0.000    0.000    0.000 zmqstream.py:542(sending)
#         2    0.000    0.000    0.001    0.001 zmqstream.py:556(_run_callback)
#         2    0.000    0.000    0.001    0.001 zmqstream.py:583(_handle_events)
#         2    0.000    0.000    0.001    0.001 zmqstream.py:624(_handle_recv)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:659(_check_closed)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:663(_rebuild_io_state)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:686(_update_handler)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:694(<lambda>)
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         2    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#       2/1    0.000    0.000    0.103    0.103 {built-in method builtins.exec}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#     83/79    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#        24    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         4    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         5    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         3    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         8    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         2    0.004    0.002    0.008    0.004 {method '__exit__' of 'sqlite3.Connection' objects}
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#       4/3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         9    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#    400006    0.043    0.000    0.043    0.000 {method 'append' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         4    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#       2/1    0.000    0.000    0.000    0.000 {method 'poll' of 'select.epoll' objects}
#         9    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {method 'recv' of '_socket.socket' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         5    0.000    0.000    0.001    0.000 {method 'run' of '_contextvars.Context' objects}
#         1    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#         2    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         5    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}

# %%
cProfile.run("main()", sort=True)  # Order is based on tottime, percall, ncalls
# Out:
# Array created successfully
#          400737 function calls (400729 primitive calls) in 0.115 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.051    0.051    0.086    0.086 1140210951.py:2(create_array)
#    400007    0.043    0.000    0.043    0.000 {method 'append' of 'list' objects}
#       2/1    0.008    0.004    0.111    0.111 {built-in method builtins.exec}
#         2    0.007    0.004    0.012    0.006 {method '__exit__' of 'sqlite3.Connection' objects}
#         1    0.003    0.003    0.090    0.090 1140210951.py:12(main)
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         4    0.000    0.000    0.000    0.000 {method 'poll' of 'select.epoll' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        15    0.000    0.000    0.000    0.000 socket.py:626(send)
#         7    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#         2    0.000    0.000    0.000    0.000 iostream.py:655(write)
#         4    0.000    0.000    0.001    0.000 base_events.py:1894(_run_once)
#         4    0.000    0.000    0.000    0.000 selectors.py:451(select)
#         7    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#         3    0.000    0.000    0.000    0.000 socket.py:774(recv_multipart)
#     97/91    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        38    0.000    0.000    0.000    0.000 enum.py:713(__call__)
#        17    0.000    0.000    0.000    0.000 enum.py:1531(__or__)
#         2    0.000    0.000    0.000    0.000 socket.py:703(send_multipart)
#        11    0.000    0.000    0.000    0.000 enum.py:1541(__and__)
#         3    0.000    0.000    0.001    0.000 zmqstream.py:583(_handle_events)
#        38    0.000    0.000    0.000    0.000 enum.py:1116(__new__)
#         1    0.000    0.000    0.000    0.000 inspect.py:3119(_bind)
#         9    0.000    0.000    0.000    0.000 typing.py:378(inner)
#         2    0.000    0.000    0.000    0.000 {method 'recv' of '_socket.socket' objects}
#         4    0.000    0.000    0.000    0.000 zmqstream.py:663(_rebuild_io_state)
#         5    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         7    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         6    0.000    0.000    0.001    0.000 {method 'run' of '_contextvars.Context' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         6    0.000    0.000    0.001    0.000 events.py:82(_run)
#         1    0.000    0.000    0.000    0.000 poll.py:80(poll)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:624(_handle_recv)
#         3    0.000    0.000    0.000    0.000 iostream.py:157(_handle_event)
#         4    0.000    0.000    0.000    0.000 events.py:32(__init__)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:302(poll_control_queue)
#         6    0.000    0.000    0.000    0.000 typing.py:1239(__hash__)
#         8    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         4    0.000    0.000    0.000    0.000 zmqstream.py:686(_update_handler)
#         2    0.000    0.000    0.000    0.000 iostream.py:278(_really_send)
#         1    0.000    0.000    0.012    0.012 history.py:845(writeout_cache)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         1    0.000    0.000    0.000    0.000 zmqstream.py:427(flush)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         1    0.000    0.000    0.000    0.000 base_events.py:764(call_at)
#         1    0.000    0.000    0.000    0.000 1140210951.py:8(print_statement)
#        29    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 kernelbase.py:324(_flush)
#         5    0.000    0.000    0.000    0.000 selector_events.py:746(_process_events)
#         1    0.000    0.000    0.000    0.000 selector_events.py:129(_read_from_self)
#         1    0.000    0.000    0.000    0.000 queues.py:225(get)
#         1    0.000    0.000    0.000    0.000 queues.py:209(put_nowait)
#         3    0.000    0.000    0.000    0.000 base_events.py:811(_call_soon)
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         3    0.000    0.000    0.000    0.000 typing.py:1446(__subclasscheck__)
#         8    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         8    0.000    0.000    0.000    0.000 base_events.py:731(time)
#         1    0.000    0.000    0.000    0.000 base_events.py:740(call_later)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:556(_run_callback)
#         7    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         1    0.000    0.000    0.000    0.000 _base.py:537(set_result)
#         3    0.000    0.000    0.000    0.000 typing.py:1175(__instancecheck__)
#         3    0.000    0.000    0.000    0.000 base_events.py:1879(_add_callback)
#         2    0.000    0.000    0.000    0.000 iostream.py:577(_schedule_flush)
#         1    0.000    0.000    0.000    0.000 asyncio.py:225(add_callback)
#         1    0.000    0.000    0.000    0.000 asyncio.py:210(call_at)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         1    0.000    0.000    0.000    0.000 inspect.py:2935(apply_defaults)
#         1    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#         2    0.000    0.000    0.000    0.000 iostream.py:276(<lambda>)
#         1    0.000    0.000    0.000    0.000 queues.py:186(put)
#         2    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#         2    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#         2    0.000    0.000    0.001    0.000 asyncio.py:200(_handle_events)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         1    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#         1    0.000    0.000    0.000    0.000 inspect.py:2882(args)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         1    0.000    0.000    0.013    0.013 history.py:55(only_when_enabled)
#         1    0.000    0.000    0.000    0.000 iostream.py:259(schedule)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         1    0.000    0.000    0.013    0.013 decorator.py:229(fun)
#         3    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         5    0.000    0.000    0.000    0.000 zmqstream.py:542(sending)
#         4    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#        10    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 ioloop.py:596(call_later)
#         3    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 ioloop.py:541(time)
#        11    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         7    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 concurrent.py:182(future_set_result_unless_cancelled)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         1    0.000    0.000    0.000    0.000 threading.py:1220(is_alive)
#         2    0.000    0.000    0.000    0.000 ioloop.py:742(_run_callback)
#       4/3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 iostream.py:587(_schedule_in_thread)
#         2    0.000    0.000    0.000    0.000 base_events.py:782(call_soon)
#         1    0.000    0.000    0.000    0.000 futures.py:394(_call_set_state)
#         3    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         9    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         8    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         1    0.000    0.000    0.000    0.000 events.py:107(__init__)
#         1    0.000    0.000    0.000    0.000 queues.py:256(get_nowait)
#        29    0.000    0.000    0.000    0.000 typing.py:2119(cast)
#         5    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         2    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         1    0.000    0.000    0.000    0.000 {built-in method _heapq.heappush}
#         3    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         1    0.000    0.000    0.000    0.000 inspect.py:2905(kwargs)
#         1    0.000    0.000    0.000    0.000 queues.py:317(__put_internal)
#         1    0.000    0.000    0.000    0.000 base_events.py:835(call_soon_threadsafe)
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#         1    0.000    0.000    0.000    0.000 threading.py:424(notify_all)
#         3    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         2    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 selector_events.py:141(_write_to_self)
#         1    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         1    0.000    0.000    0.090    0.090 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         2    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:468(update_flag)
#         1    0.000    0.000    0.012    0.012 history.py:833(_writeout_input_cache)
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         1    0.000    0.000    0.000    0.000 threading.py:394(notify)
#         1    0.000    0.000    0.000    0.000 inspect.py:3254(bind)
#         1    0.000    0.000    0.000    0.000 poll.py:31(register)
#         3    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         2    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         2    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#        10    0.000    0.000    0.000    0.000 inspect.py:2794(kind)
#         3    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         1    0.000    0.000    0.000    0.000 _base.py:337(_invoke_callbacks)
#         7    0.000    0.000    0.000    0.000 zmqstream.py:538(receiving)
#         1    0.000    0.000    0.000    0.000 threading.py:1153(_wait_for_tstate_lock)
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         6    0.000    0.000    0.000    0.000 base_events.py:1989(get_debug)
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 base_events.py:537(_check_closed)
#         4    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 events.py:123(__lt__)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:694(<lambda>)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.000    0.000    0.000    0.000 queues.py:312(_put)
#         2    0.000    0.000    0.000    0.000 {built-in method time.time}
#         1    0.000    0.000    0.000    0.000 queues.py:309(_get)
#         1    0.000    0.000    0.000    0.000 unix_events.py:81(_process_self_data)
#         2    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         4    0.000    0.000    0.000    0.000 inspect.py:2782(name)
#         4    0.000    0.000    0.000    0.000 inspect.py:3075(parameters)
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 queues.py:177(empty)
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         2    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:659(_check_closed)
#         1    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:601(is_set)
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 locks.py:224(clear)
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 base_events.py:717(is_closed)
#         1    0.000    0.000    0.000    0.000 inspect.py:2874(__init__)

# %%
cProfile.run("main()", sort="ncalls")  # Order is ncalls
# Out:
# Array created successfully
#          400620 function calls (400608 primitive calls) in 0.147 seconds
#
#    Ordered by: call count
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    400006    0.061    0.000    0.061    0.000 {method 'append' of 'list' objects}
#     83/79    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        31    0.000    0.000    0.000    0.000 enum.py:1116(__new__)
#        31    0.000    0.000    0.000    0.000 enum.py:713(__call__)
#        28    0.000    0.000    0.000    0.000 typing.py:2119(cast)
#        24    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        16    0.000    0.000    0.000    0.000 enum.py:1531(__or__)
#        15    0.003    0.000    0.005    0.000 socket.py:626(send)
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#        10    0.000    0.000    0.000    0.000 inspect.py:2794(kind)
#         9    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         9    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         8    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         8    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         8    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         8    0.000    0.000    0.000    0.000 enum.py:1541(__and__)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         6    0.000    0.000    0.000    0.000 typing.py:378(inner)
#         5    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#       5/3    0.000    0.000    0.006    0.002 {method 'run' of '_contextvars.Context' objects}
#         5    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         5    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#       5/3    0.000    0.000    0.006    0.002 events.py:82(_run)
#         5    0.000    0.000    0.000    0.000 zmqstream.py:538(receiving)
#         5    0.000    0.000    0.000    0.000 base_events.py:1989(get_debug)
#         5    0.000    0.000    0.000    0.000 base_events.py:731(time)
#         5    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#         4    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         4    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#       4/3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 selector_events.py:746(_process_events)
#         4    0.000    0.000    0.000    0.000 zmqstream.py:542(sending)
#         4    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         4    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         4    0.000    0.000    0.000    0.000 inspect.py:2782(name)
#         4    0.000    0.000    0.000    0.000 inspect.py:3075(parameters)
#         4    0.000    0.000    0.000    0.000 typing.py:1239(__hash__)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         3    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         3    0.000    0.000    0.006    0.002 base_events.py:1894(_run_once)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:686(_update_handler)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:663(_rebuild_io_state)
#         3    0.000    0.000    0.000    0.000 events.py:32(__init__)
#         3    0.000    0.000    0.000    0.000 base_events.py:537(_check_closed)
#         3    0.000    0.000    0.000    0.000 base_events.py:811(_call_soon)
#         3    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         3    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#       2/1    0.005    0.002    0.145    0.145 {built-in method builtins.exec}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         2    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         2    0.000    0.000    0.005    0.003 socket.py:703(send_multipart)
#       2/1    0.000    0.000    0.000    0.000 selectors.py:451(select)
#         2    0.000    0.000    0.000    0.000 socket.py:774(recv_multipart)
#         2    0.000    0.000    0.000    0.000 traitlets.py:689(set)
#         2    0.000    0.000    0.000    0.000 traitlets.py:727(_cross_validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3486(validate_elements)
#         2    0.000    0.000    0.006    0.003 zmqstream.py:624(_handle_recv)
#         2    0.000    0.000    0.006    0.003 zmqstream.py:583(_handle_events)
#         2    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#         2    0.000    0.000    0.000    0.000 iostream.py:505(parent_header)
#         2    0.000    0.000    0.000    0.000 iostream.py:655(write)
#         2    0.000    0.000    0.000    0.000 iostream.py:550(_is_master_process)
#         2    0.000    0.000    0.000    0.000 iostream.py:577(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         2    0.000    0.000    0.005    0.003 iostream.py:157(_handle_event)
#         2    0.000    0.000    0.005    0.003 iostream.py:276(<lambda>)
#         2    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         2    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         2    0.000    0.000    0.005    0.003 iostream.py:278(_really_send)
#         2    0.005    0.002    0.008    0.004 {method '__exit__' of 'sqlite3.Connection' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:708(__set__)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3631(set)
#         2    0.000    0.000    0.000    0.000 ioloop.py:742(_run_callback)
#         2    0.000    0.000    0.000    0.000 traitlets.py:2304(validate)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3624(validate_elements)
#         2    0.000    0.000    0.006    0.003 zmqstream.py:556(_run_callback)
#         2    0.000    0.000    0.000    0.000 traitlets.py:3474(validate)
#         2    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         2    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         2    0.000    0.000    0.000    0.000 {method 'recv' of '_socket.socket' objects}
#         2    0.000    0.000    0.000    0.000 traitlets.py:718(_validate)
#       2/1    0.000    0.000    0.000    0.000 {method 'poll' of 'select.epoll' objects}
#         2    0.000    0.000    0.000    0.000 base_events.py:1879(_add_callback)
#         2    0.000    0.000    0.000    0.000 typing.py:1175(__instancecheck__)
#         2    0.000    0.000    0.000    0.000 base_events.py:782(call_soon)
#         2    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         2    0.000    0.000    0.000    0.000 typing.py:1446(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 _base.py:537(set_result)
#         1    0.000    0.000    0.000    0.000 inspect.py:2905(kwargs)
#         1    0.000    0.000    0.000    0.000 inspect.py:2882(args)
#         1    0.000    0.000    0.000    0.000 inspect.py:2935(apply_defaults)
#         1    0.000    0.000    0.000    0.000 inspect.py:3119(_bind)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1527(_notify_observers)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:427(flush)
#         1    0.000    0.000    0.013    0.013 history.py:845(writeout_cache)
#         1    0.000    0.000    0.000    0.000 iostream.py:138(_event_pipe)
#         1    0.000    0.000    0.000    0.000 queues.py:209(put_nowait)
#         1    0.000    0.000    0.000    0.000 queues.py:256(get_nowait)
#         1    0.000    0.000    0.000    0.000 asyncio.py:225(add_callback)
#         1    0.067    0.067    0.118    0.118 1140210951.py:2(create_array)
#         1    0.000    0.000    0.000    0.000 1140210951.py:8(print_statement)
#         1    0.000    0.000    0.121    0.121 <string>:1(<module>)
#         1    0.003    0.003    0.121    0.121 1140210951.py:12(main)
#         1    0.000    0.000    0.006    0.006 asyncio.py:200(_handle_events)
#         1    0.000    0.000    0.000    0.000 queues.py:309(_get)
#         1    0.000    0.000    0.000    0.000 queues.py:312(_put)
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         1    0.000    0.000    0.000    0.000 queues.py:177(empty)
#         1    0.000    0.000    0.000    0.000 locks.py:224(clear)
#         1    0.000    0.000    0.000    0.000 queues.py:225(get)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:302(poll_control_queue)
#         1    0.000    0.000    0.000    0.000 queues.py:186(put)
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:324(_flush)
#         1    0.000    0.000    0.000    0.000 queues.py:317(__put_internal)
#         1    0.000    0.000    0.000    0.000 iostream.py:259(schedule)
#         1    0.000    0.000    0.019    0.019 decorator.py:229(fun)
#         1    0.000    0.000    0.013    0.013 history.py:833(_writeout_input_cache)
#         1    0.000    0.000    0.000    0.000 history.py:839(_writeout_output_cache)
#         1    0.000    0.000    0.019    0.019 history.py:55(only_when_enabled)
#         1    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 zmqstream.py:659(_check_closed)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:694(<lambda>)
#         1    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         1    0.003    0.003    0.005    0.005 {method 'execute' of 'sqlite3.Connection' objects}
#         1    0.000    0.000    0.000    0.000 concurrent.py:182(future_set_result_unless_cancelled)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:468(update_flag)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 unix_events.py:81(_process_self_data)
#         1    0.000    0.000    0.000    0.000 traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         1    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 selector_events.py:129(_read_from_self)
#         1    0.000    0.000    0.000    0.000 selector_events.py:141(_write_to_self)
#         1    0.000    0.000    0.000    0.000 inspect.py:2874(__init__)
#         1    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:3254(bind)
#         1    0.000    0.000    0.000    0.000 threading.py:424(notify_all)
#         1    0.000    0.000    0.000    0.000 _base.py:337(_invoke_callbacks)
#         1    0.000    0.000    0.000    0.000 base_events.py:717(is_closed)
#         1    0.000    0.000    0.000    0.000 poll.py:31(register)
#         1    0.000    0.000    0.000    0.000 poll.py:80(poll)
#         1    0.000    0.000    0.000    0.000 futures.py:394(_call_set_state)
#         1    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#         1    0.000    0.000    0.000    0.000 threading.py:314(_is_owned)
#         1    0.000    0.000    0.000    0.000 base_events.py:835(call_soon_threadsafe)
#         1    0.000    0.000    0.000    0.000 threading.py:308(_release_save)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         1    0.000    0.000    0.000    0.000 threading.py:601(is_set)
#         1    0.000    0.000    0.000    0.000 threading.py:1220(is_alive)
#         1    0.000    0.000    0.000    0.000 threading.py:394(notify)
#         1    0.000    0.000    0.000    0.000 threading.py:1153(_wait_for_tstate_lock)

# %%
cProfile.run("main()", sort="ncalls", filename="profile.txt")  # Order is ncalls
# Out:
# Array created successfully

# %%
# !cat profile.txt

# %% [markdown]
# ### Profiling multiple functions or methods together

# %%
def using_range(nums):
    successive_diffs = []
    for i in range(len(nums)):
        if i == 0:
            continue
        successive_diffs.append(nums[i - 1] - nums[i])
    return successive_diffs


def using_enumerate(nums):
    successive_diffs = []
    for i, num in enumerate(nums):
        if i == 0:
            continue
        successive_diffs.append(nums[i - 1] - nums[i])
    return successive_diffs

# %%
cProfile.run("using_range(range(10000))")
# Out:
#          10004 function calls in 0.004 seconds
#
#    Ordered by: standard name
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.003    0.003    0.004    0.004 3792339585.py:1(using_range)
#         1    0.000    0.000    0.004    0.004 <string>:1(<module>)
#         1    0.000    0.000    0.004    0.004 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#      9999    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}

# %%
cProfile.run("using_enumerate(range(10000))", sort=True)
# Out:
#          10364 function calls (10359 primitive calls) in 0.010 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.005    0.002    0.002    0.002 {built-in method builtins.exec}
#     10004    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#         1    0.001    0.001    0.002    0.002 3792339585.py:10(using_enumerate)
#         1    0.001    0.001    0.003    0.003 history.py:845(writeout_cache)
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#        14    0.000    0.000    0.000    0.000 socket.py:626(send)
#        26    0.000    0.000    0.000    0.000 enum.py:713(__call__)
#         2    0.000    0.000    0.000    0.000 socket.py:703(send_multipart)
#         4    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:624(_handle_recv)
#        14    0.000    0.000    0.000    0.000 enum.py:1531(__or__)
#         1    0.000    0.000    0.000    0.000 inspect.py:3119(_bind)
#     64/60    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         2    0.000    0.000    0.000    0.000 socket.py:774(recv_multipart)
#         4    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#         2    0.000    0.000    0.001    0.000 zmqstream.py:583(_handle_events)
#        26    0.000    0.000    0.000    0.000 enum.py:1116(__new__)
#         2    0.000    0.000    0.000    0.000 iostream.py:278(_really_send)
#         6    0.000    0.000    0.000    0.000 enum.py:1541(__and__)
#         6    0.000    0.000    0.000    0.000 typing.py:378(inner)
#         1    0.000    0.000    0.002    0.002 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 inspect.py:2935(apply_defaults)
#         2    0.000    0.000    0.000    0.000 iostream.py:276(<lambda>)
#         1    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         2    0.000    0.000    0.000    0.000 iostream.py:157(_handle_event)
#         1    0.000    0.000    0.000    0.000 base_events.py:1894(_run_once)
#         1    0.000    0.000    0.000    0.000 asyncio.py:225(add_callback)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:663(_rebuild_io_state)
#         4    0.000    0.000    0.000    0.000 typing.py:1239(__hash__)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:686(_update_handler)
#         1    0.000    0.000    0.000    0.000 base_events.py:1879(_add_callback)
#         4    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         2    0.000    0.000    0.001    0.000 events.py:82(_run)
#         1    0.000    0.000    0.000    0.000 selectors.py:451(select)
#         2    0.000    0.000    0.000    0.000 typing.py:1446(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:556(_run_callback)
#         1    0.000    0.000    0.000    0.000 inspect.py:2882(args)
#         1    0.000    0.000    0.000    0.000 inspect.py:3254(bind)
#         1    0.000    0.000    0.003    0.003 history.py:55(only_when_enabled)
#         1    0.000    0.000    0.003    0.003 decorator.py:229(fun)
#         4    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         2    0.000    0.000    0.001    0.000 {method 'run' of '_contextvars.Context' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         2    0.000    0.000    0.000    0.000 typing.py:1175(__instancecheck__)
#         1    0.000    0.000    0.000    0.000 events.py:32(__init__)
#         1    0.000    0.000    0.000    0.000 base_events.py:811(_call_soon)
#         2    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         2    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         2    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         3    0.000    0.000    0.000    0.000 base_events.py:731(time)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 asyncio.py:200(_handle_events)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#        10    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 {method 'poll' of 'select.epoll' objects}
#         2    0.000    0.000    0.000    0.000 selector_events.py:746(_process_events)
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#         1    0.000    0.000    0.000    0.000 inspect.py:2905(kwargs)
#         1    0.000    0.000    0.000    0.000 base_events.py:782(call_soon)
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         4    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         4    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 zmqstream.py:542(sending)
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 ioloop.py:742(_run_callback)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         2    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         3    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#        10    0.000    0.000    0.000    0.000 inspect.py:2794(kind)
#        10    0.000    0.000    0.000    0.000 typing.py:2119(cast)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         1    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         4    0.000    0.000    0.000    0.000 zmqstream.py:538(receiving)
#         2    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         1    0.000    0.000    0.000    0.000 zmqstream.py:694(<lambda>)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         4    0.000    0.000    0.000    0.000 inspect.py:2782(name)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         2    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         4    0.000    0.000    0.000    0.000 inspect.py:3075(parameters)
#         1    0.000    0.000    0.000    0.000 base_events.py:537(_check_closed)
#         1    0.000    0.000    0.000    0.000 inspect.py:2874(__init__)
#         1    0.000    0.000    0.000    0.000 base_events.py:1989(get_debug)

# %%
cProfile.run("using_range(range(10000));using_enumerate(range(10000))", sort=True)
# Out:
#          20295 function calls (20290 primitive calls) in 0.012 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.005    0.002    0.005    0.005 {built-in method builtins.exec}
#         1    0.003    0.003    0.004    0.004 3792339585.py:10(using_enumerate)
#     19999    0.003    0.000    0.003    0.000 {method 'append' of 'list' objects}
#         1    0.001    0.001    0.001    0.001 3792339585.py:1(using_range)
#        14    0.000    0.000    0.000    0.000 socket.py:626(send)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         2    0.000    0.000    0.000    0.000 socket.py:774(recv_multipart)
#         2    0.000    0.000    0.000    0.000 socket.py:703(send_multipart)
#         4    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#        14    0.000    0.000    0.000    0.000 enum.py:1531(__or__)
#     64/60    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        26    0.000    0.000    0.000    0.000 enum.py:713(__call__)
#         4    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#         1    0.000    0.000    0.005    0.005 <string>:1(<module>)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:663(_rebuild_io_state)
#         2    0.000    0.000    0.001    0.000 zmqstream.py:583(_handle_events)
#        26    0.000    0.000    0.000    0.000 enum.py:1116(__new__)
#         6    0.000    0.000    0.000    0.000 enum.py:1541(__and__)
#         1    0.000    0.000    0.000    0.000 {method 'poll' of 'select.epoll' objects}
#         6    0.000    0.000    0.000    0.000 typing.py:378(inner)
#         2    0.000    0.000    0.000    0.000 iostream.py:278(_really_send)
#         1    0.000    0.000    0.000    0.000 base_events.py:1894(_run_once)
#         2    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         4    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         2    0.000    0.000    0.000    0.000 iostream.py:157(_handle_event)
#         1    0.000    0.000    0.000    0.000 asyncio.py:225(add_callback)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:686(_update_handler)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:624(_handle_recv)
#         1    0.000    0.000    0.000    0.000 selectors.py:451(select)
#         2    0.000    0.000    0.000    0.000 iostream.py:276(<lambda>)
#         4    0.000    0.000    0.000    0.000 typing.py:1239(__hash__)
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 typing.py:1446(__subclasscheck__)
#         2    0.000    0.000    0.001    0.000 events.py:82(_run)
#         1    0.000    0.000    0.000    0.000 base_events.py:1879(_add_callback)
#         2    0.000    0.000    0.001    0.000 {method 'run' of '_contextvars.Context' objects}
#         2    0.000    0.000    0.000    0.000 zmqstream.py:556(_run_callback)
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         2    0.000    0.000    0.000    0.000 typing.py:1175(__instancecheck__)
#         3    0.000    0.000    0.000    0.000 base_events.py:731(time)
#         1    0.000    0.000    0.000    0.000 events.py:32(__init__)
#        11    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#         1    0.000    0.000    0.000    0.000 base_events.py:811(_call_soon)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         1    0.000    0.000    0.000    0.000 asyncio.py:200(_handle_events)
#         2    0.000    0.000    0.000    0.000 selector_events.py:746(_process_events)
#         1    0.000    0.000    0.000    0.000 base_events.py:782(call_soon)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         4    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 ioloop.py:742(_run_callback)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:542(sending)
#         2    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         4    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         3    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         2    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         1    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         2    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 zmqstream.py:694(<lambda>)
#         4    0.000    0.000    0.000    0.000 zmqstream.py:538(receiving)
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         1    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         2    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         2    0.000    0.000    0.000    0.000 typing.py:2119(cast)
#         1    0.000    0.000    0.000    0.000 base_events.py:1989(get_debug)
#         1    0.000    0.000    0.000    0.000 base_events.py:537(_check_closed)

# %% [markdown]
# ### Comparing two functions

# %%
cProfile.runctx(
    "using_range(range(10000))", globals(), locals(), sort="time"
)  # filename='profile1.txt')
cProfile.runctx(
    "using_enumerate(range(10000))", globals(), locals(), sort="time"
)  # filename='profile2.txt')
# Out:
#          10004 function calls in 0.004 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.003    0.003    0.004    0.004 3792339585.py:1(using_range)
#      9999    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.004    0.004 {built-in method builtins.exec}
#         1    0.000    0.000    0.004    0.004 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#
#
#          10072 function calls (10071 primitive calls) in 0.004 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.003    0.003    0.004    0.004 3792339585.py:10(using_enumerate)
#     10003    0.001    0.000    0.001    0.000 {method 'append' of 'list' objects}
#       2/1    0.000    0.000    0.004    0.004 {built-in method builtins.exec}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:3119(_bind)
#         1    0.000    0.000    0.004    0.004 <string>:1(<module>)
#         1    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#         1    0.000    0.000    0.004    0.004 history.py:55(only_when_enabled)
#         1    0.000    0.000    0.000    0.000 inspect.py:3254(bind)
#         4    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         1    0.000    0.000    0.000    0.000 inspect.py:2935(apply_defaults)
#         4    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         1    0.000    0.000    0.004    0.004 decorator.py:229(fun)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         1    0.000    0.000    0.000    0.000 inspect.py:2882(args)
#         2    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         1    0.000    0.000    0.000    0.000 inspect.py:2905(kwargs)
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#        10    0.000    0.000    0.000    0.000 inspect.py:2794(kind)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         8    0.000    0.000    0.000    0.000 typing.py:2119(cast)
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 inspect.py:2782(name)
#         4    0.000    0.000    0.000    0.000 inspect.py:3075(parameters)
#         1    0.000    0.000    0.000    0.000 inspect.py:2874(__init__)

# %% [markdown]
# ### Profiling with line-by-line analysis

# %%
def create_array():
    arr = []
    for i in range(0, 400000):
        arr.append(i)


def print_statement():
    print("Array created successfully")


def main():
    create_array()
    print_statement()


if __name__ == "__main__":
    import cProfile
    import pstats

    profiler = cProfile.Profile()
    profiler.enable()
    main()
    profiler.disable()

    stats = pstats.Stats(profiler).sort_stats("ncalls")
    stats.print_stats()
# Out:
# Array created successfully
#          400405 function calls (400400 primitive calls) in 0.104 seconds
#
#    Ordered by: call count
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#    400004    0.042    0.000    0.042    0.000 {method 'append' of 'list' objects}
#     61/57    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#        23    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/typing.py:2119(cast)
#        22    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/enum.py:1116(__new__)
#        22    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/enum.py:713(__call__)
#        14    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/zmq/sugar/socket.py:626(send)
#        13    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/enum.py:1531(__or__)
#        12    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#        10    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/inspect.py:2794(kind)
#         8    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         6    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         6    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/traitlets/traitlets.py:629(get)
#         6    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/traitlets/traitlets.py:676(__get__)
#         5    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/enum.py:1541(__and__)
#         4    0.000    0.000    0.000    0.000 {method 'get' of 'dict' objects}
#       4/3    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/inspect.py:2782(name)
#         4    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/inspect.py:3075(parameters)
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         3    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         3    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         3    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         3    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         3    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         3    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/zmq/sugar/attrsettr.py:43(__getattr__)
#         3    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:538(receiving)
#         3    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/typing.py:378(inner)
#         3    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/zmq/sugar/attrsettr.py:66(_get_attr_opt)
#         2    0.000    0.000    0.000    0.000 {method 'extend' of 'list' objects}
#         2    0.000    0.000    0.000    0.000 {method 'items' of 'dict' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         2    0.000    0.000    0.000    0.000 {method 'get' of '_contextvars.ContextVar' objects}
#         2    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         2    0.000    0.000    0.000    0.000 {method 'write' of '_io.StringIO' objects}
#         2    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         2    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/traitlets/traitlets.py:689(set)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/traitlets/traitlets.py:727(_cross_validate)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/traitlets/traitlets.py:3486(validate_elements)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/ipykernel/iostream.py:505(parent_header)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/ipykernel/iostream.py:655(write)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/ipykernel/iostream.py:550(_is_master_process)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/ipykernel/iostream.py:577(_schedule_flush)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:686(_update_handler)
#         2    0.004    0.002    0.007    0.003 {method '__exit__' of 'sqlite3.Connection' objects}
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:542(sending)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/traitlets/traitlets.py:708(__set__)
#         2    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/queue.py:97(empty)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/traitlets/traitlets.py:3631(set)
#         2    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/queue.py:209(_qsize)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/traitlets/traitlets.py:2304(validate)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/traitlets/traitlets.py:3624(validate_elements)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:663(_rebuild_io_state)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/traitlets/traitlets.py:3474(validate)
#         2    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/traitlets/traitlets.py:718(_validate)
#         2    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/base_events.py:731(time)
#         2    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/typing.py:1239(__hash__)
#         2    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/typing.py:1175(__instancecheck__)
#         2    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/threading.py:299(__enter__)
#         2    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/threading.py:302(__exit__)
#         2    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/typing.py:1446(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.print}
#         1    0.000    0.000    0.000    0.000 {method 'run' of '_contextvars.Context' objects}
#         1    0.000    0.000    0.000    0.000 {built-in method _thread.allocate_lock}
#         1    0.000    0.000    0.000    0.000 {method 'release' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/zmq/sugar/socket.py:703(send_multipart)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/selectors.py:451(select)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/zmq/sugar/socket.py:774(recv_multipart)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/base_events.py:1894(_run_once)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/events.py:82(_run)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/inspect.py:2905(kwargs)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/inspect.py:2882(args)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/inspect.py:2935(apply_defaults)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/inspect.py:3119(_bind)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/selector_events.py:746(_process_events)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/traitlets/traitlets.py:1527(_notify_observers)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:624(_handle_recv)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:583(_handle_events)
#         1    0.000    0.000    0.017    0.017 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/IPython/core/history.py:845(writeout_cache)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/ipykernel/iostream.py:138(_event_pipe)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/tornado/platform/asyncio.py:225(add_callback)
#         1    0.048    0.048    0.082    0.082 /tmp/ipykernel_8416/267384398.py:1(create_array)
#         1    0.000    0.000    0.000    0.000 /tmp/ipykernel_8416/267384398.py:7(print_statement)
#         1    0.003    0.003    0.085    0.085 /tmp/ipykernel_8416/267384398.py:11(main)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/ipykernel/iostream.py:213(_is_master_process)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/ipykernel/iostream.py:157(_handle_event)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/ipykernel/iostream.py:276(<lambda>)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/ipykernel/iostream.py:255(closed)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/ipykernel/iostream.py:216(_check_mp_mode)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/ipykernel/iostream.py:259(schedule)
#         1    0.000    0.000    0.017    0.017 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/IPython/core/history.py:833(_writeout_input_cache)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/IPython/core/history.py:839(_writeout_output_cache)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/decorator.py:199(fix)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/ipykernel/iostream.py:278(_really_send)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:694(<lambda>)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/dateutil/tz/tz.py:74(utcoffset)
#         1    0.006    0.006    0.010    0.010 {method 'execute' of 'sqlite3.Connection' objects}
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/traitlets/traitlets.py:1523(notify_change)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/tornado/ioloop.py:742(_run_callback)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/traitlets/traitlets.py:1512(_notify_trait)
#         1    0.000    0.000    0.000    0.000 /workspaces/PythonBatchNovDec2024/project_k/lib/python3.12/site-packages/zmq/eventloop/zmqstream.py:556(_run_callback)
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         1    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/inspect.py:2874(__init__)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/inspect.py:3254(bind)
#         1    0.000    0.000    0.000    0.000 {method 'poll' of 'select.epoll' objects}
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/base_events.py:1989(get_debug)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/events.py:32(__init__)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/base_events.py:537(_check_closed)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/base_events.py:811(_call_soon)
#         1    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/threading.py:627(clear)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/threading.py:314(_is_owned)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/asyncio/base_events.py:782(call_soon)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/threading.py:308(_release_save)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/threading.py:311(_acquire_restore)
#         1    0.000    0.000    0.085    0.085 /usr/local/python/3.12.1/lib/python3.12/threading.py:637(wait)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/threading.py:601(is_set)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/threading.py:1220(is_alive)
#         1    0.000    0.000    0.000    0.000 /usr/local/python/3.12.1/lib/python3.12/threading.py:1153(_wait_for_tstate_lock)

# %%
# Export profiler output to file
stats = pstats.Stats(profiler)
stats.dump_stats("export-data.txt")

# %% [markdown]
# ### Profiling memory usage
#
#
#     pip install memory_profiler

# %%
cProfile.runctx("using_range(range(10000))", globals(), locals(), sort="time")
# Out:
#          10514 function calls (10508 primitive calls) in 0.011 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#       2/1    0.004    0.002    0.004    0.004 {built-in method builtins.exec}
#         1    0.003    0.003    0.004    0.004 3792339585.py:1(using_range)
#     10005    0.002    0.000    0.002    0.000 {method 'append' of 'list' objects}
#         1    0.000    0.000    0.000    0.000 {method 'execute' of 'sqlite3.Connection' objects}
#         3    0.000    0.000    0.000    0.000 selectors.py:451(select)
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         4    0.000    0.000    0.006    0.002 base_events.py:1894(_run_once)
#        14    0.000    0.000    0.000    0.000 socket.py:626(send)
#         2    0.000    0.000    0.000    0.000 {method 'recv' of '_socket.socket' objects}
#         5    0.000    0.000    0.000    0.000 attrsettr.py:66(_get_attr_opt)
#         2    0.000    0.000    0.000    0.000 socket.py:703(send_multipart)
#        16    0.000    0.000    0.000    0.000 enum.py:1531(__or__)
#         5    0.000    0.000    0.000    0.000 attrsettr.py:43(__getattr__)
#        31    0.000    0.000    0.000    0.000 enum.py:713(__call__)
#     74/70    0.000    0.000    0.000    0.000 {built-in method builtins.isinstance}
#         1    0.000    0.000    0.000    0.000 inspect.py:3119(_bind)
#         8    0.000    0.000    0.000    0.000 enum.py:1541(__and__)
#         1    0.000    0.000    0.000    0.000 poll.py:80(poll)
#         2    0.000    0.000    0.000    0.000 socket.py:774(recv_multipart)
#        31    0.000    0.000    0.000    0.000 enum.py:1116(__new__)
#         1    0.000    0.000    0.004    0.004 <string>:1(<module>)
#         5    0.000    0.000    0.001    0.000 {method 'run' of '_contextvars.Context' objects}
#         1    0.000    0.000    0.000    0.000 kernelbase.py:302(poll_control_queue)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:583(_handle_events)
#         4    0.000    0.000    0.000    0.000 queue.py:97(empty)
#         1    0.000    0.000    0.000    0.000 selector_events.py:129(_read_from_self)
#         1    0.000    0.000    0.000    0.000 kernelbase.py:324(_flush)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:427(flush)
#         5    0.000    0.000    0.001    0.000 events.py:82(_run)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:686(_update_handler)
#         6    0.000    0.000    0.000    0.000 typing.py:378(inner)
#         2    0.000    0.000    0.000    0.000 iostream.py:278(_really_send)
#         3    0.000    0.000    0.000    0.000 zmqstream.py:663(_rebuild_io_state)
#         1    0.000    0.000    0.005    0.005 history.py:845(writeout_cache)
#         3    0.000    0.000    0.000    0.000 events.py:32(__init__)
#         5    0.000    0.000    0.000    0.000 <frozen importlib._bootstrap>:1390(_handle_fromlist)
#         1    0.000    0.000    0.000    0.000 queues.py:186(put)
#         6    0.000    0.000    0.000    0.000 traitlets.py:676(__get__)
#         1    0.000    0.000    0.000    0.000 decorator.py:199(fix)
#         1    0.000    0.000    0.000    0.000 _base.py:537(set_result)
#         3    0.000    0.000    0.000    0.000 base_events.py:811(_call_soon)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:624(_handle_recv)
#         1    0.000    0.000    0.000    0.000 queues.py:225(get)
#         2    0.000    0.000    0.000    0.000 iostream.py:157(_handle_event)
#         6    0.000    0.000    0.000    0.000 traitlets.py:629(get)
#         4    0.000    0.000    0.000    0.000 typing.py:1239(__hash__)
#         1    0.000    0.000    0.000    0.000 queues.py:209(put_nowait)
#         1    0.000    0.000    0.000    0.000 futures.py:394(_call_set_state)
#         1    0.000    0.000    0.000    0.000 {method 'send' of '_socket.socket' objects}
#        21    0.000    0.000    0.000    0.000 {built-in method builtins.len}
#       2/1    0.000    0.000    0.000    0.000 {method 'poll' of 'select.epoll' objects}
#         2    0.000    0.000    0.000    0.000 iostream.py:276(<lambda>)
#         1    0.000    0.000    0.000    0.000 inspect.py:2935(apply_defaults)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.max}
#         4    0.000    0.000    0.000    0.000 selector_events.py:746(_process_events)
#         1    0.000    0.000    0.000    0.000 inspect.py:3254(bind)
#         1    0.000    0.000    0.000    0.000 asyncio.py:225(add_callback)
#         2    0.000    0.000    0.000    0.000 typing.py:1446(__subclasscheck__)
#         1    0.000    0.000    0.000    0.000 zmqstream.py:468(update_flag)
#         2    0.000    0.000    0.000    0.000 base_events.py:1879(_add_callback)
#         1    0.000    0.000    0.005    0.005 history.py:55(only_when_enabled)
#         1    0.000    0.000    0.005    0.005 decorator.py:229(fun)
#         2    0.000    0.000    0.000    0.000 zmqstream.py:556(_run_callback)
#         1    0.000    0.000    0.000    0.000 inspect.py:2882(args)
#         2    0.000    0.000    0.000    0.000 typing.py:1175(__instancecheck__)
#         5    0.000    0.000    0.000    0.000 base_events.py:731(time)
#         1    0.000    0.000    0.000    0.000 concurrent.py:182(future_set_result_unless_cancelled)
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.getattr}
#         2    0.000    0.000    0.000    0.000 queues.py:322(_consume_expired)
#         2    0.000    0.000    0.000    0.000 base_events.py:782(call_soon)
#         2    0.000    0.000    0.000    0.000 threading.py:299(__enter__)
#         2    0.000    0.000    0.000    0.000 ioloop.py:742(_run_callback)
#         1    0.000    0.000    0.000    0.000 asyncio.py:200(_handle_events)
#         9    0.000    0.000    0.000    0.000 {method 'popleft' of 'collections.deque' objects}
#         3    0.000    0.000    0.000    0.000 threading.py:302(__exit__)
#         1    0.000    0.000    0.000    0.000 threading.py:424(notify_all)
#         2    0.000    0.000    0.000    0.000 {method 'set_result' of '_asyncio.Future' objects}
#         4    0.000    0.000    0.000    0.000 zmqstream.py:542(sending)
#         1    0.000    0.000    0.000    0.000 queues.py:256(get_nowait)
#         2    0.000    0.000    0.000    0.000 iostream.py:213(_is_master_process)
#         1    0.000    0.000    0.000    0.000 base_events.py:835(call_soon_threadsafe)
#         6    0.000    0.000    0.000    0.000 {built-in method builtins.next}
#         4    0.000    0.000    0.000    0.000 queue.py:209(_qsize)
#         1    0.000    0.000    0.000    0.000 queues.py:317(__put_internal)
#         1    0.000    0.000    0.000    0.000 inspect.py:2905(kwargs)
#         7    0.000    0.000    0.000    0.000 {method 'append' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 selector_events.py:141(_write_to_self)
#         5    0.000    0.000    0.000    0.000 {method 'upper' of 'str' objects}
#         2    0.000    0.000    0.000    0.000 <frozen abc>:121(__subclasscheck__)
#         2    0.000    0.000    0.000    0.000 iostream.py:216(_check_mp_mode)
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.issubclass}
#         6    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.lock' objects}
#         5    0.000    0.000    0.000    0.000 {built-in method builtins.hasattr}
#         2    0.000    0.000    0.000    0.000 selectors.py:275(_key_from_fd)
#         1    0.000    0.000    0.000    0.000 _base.py:337(_invoke_callbacks)
#         1    0.000    0.000    0.000    0.000 threading.py:311(_acquire_restore)
#         5    0.000    0.000    0.000    0.000 {built-in method time.monotonic}
#         1    0.000    0.000    0.000    0.000 threading.py:394(notify)
#        14    0.000    0.000    0.000    0.000 typing.py:2119(cast)
#         2    0.000    0.000    0.000    0.000 {built-in method posix.getpid}
#         1    0.000    0.000    0.000    0.000 threading.py:627(clear)
#        10    0.000    0.000    0.000    0.000 inspect.py:2794(kind)
#         2    0.000    0.000    0.000    0.000 {built-in method _abc._abc_subclasscheck}
#         1    0.000    0.000    0.000    0.000 poll.py:31(register)
#         4    0.000    0.000    0.000    0.000 {built-in method builtins.hash}
#         3    0.000    0.000    0.000    0.000 {method 'items' of 'mappingproxy' objects}
#         5    0.000    0.000    0.000    0.000 zmqstream.py:538(receiving)
#         1    0.000    0.000    0.000    0.000 {built-in method math.ceil}
#         5    0.000    0.000    0.000    0.000 base_events.py:1989(get_debug)
#         1    0.000    0.000    0.000    0.000 {built-in method builtins.min}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 queues.py:173(qsize)
#         2    0.000    0.000    0.000    0.000 {built-in method _contextvars.copy_context}
#         1    0.000    0.000    0.000    0.000 unix_events.py:81(_process_self_data)
#         1    0.000    0.000    0.000    0.000 {method 'values' of 'mappingproxy' objects}
#         2    0.000    0.000    0.000    0.000 {built-in method builtins.iter}
#         1    0.000    0.000    0.000    0.000 {built-in method _asyncio.get_running_loop}
#         1    0.000    0.000    0.000    0.000 queues.py:312(_put)
#         1    0.000    0.000    0.000    0.000 {method 'acquire' of '_thread.lock' objects}
#         1    0.000    0.000    0.000    0.000 zmqstream.py:694(<lambda>)
#         4    0.000    0.000    0.000    0.000 inspect.py:3075(parameters)
#         2    0.000    0.000    0.000    0.000 {method 'cancelled' of '_asyncio.Future' objects}
#         1    0.000    0.000    0.000    0.000 zmqstream.py:659(_check_closed)
#         3    0.000    0.000    0.000    0.000 base_events.py:537(_check_closed)
#         1    0.000    0.000    0.000    0.000 queues.py:177(empty)
#         1    0.000    0.000    0.000    0.000 queues.py:309(_get)
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_thread.lock' objects}
#         4    0.000    0.000    0.000    0.000 inspect.py:2782(name)
#         1    0.000    0.000    0.000    0.000 {method 'done' of '_asyncio.Future' objects}
#         2    0.000    0.000    0.000    0.000 iostream.py:255(closed)
#         1    0.000    0.000    0.000    0.000 queues.py:59(_set_timeout)
#         1    0.000    0.000    0.000    0.000 {method '_is_owned' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 {method '__exit__' of '_thread.RLock' objects}
#         1    0.000    0.000    0.000    0.000 inspect.py:2874(__init__)
#         1    0.000    0.000    0.000    0.000 locks.py:224(clear)
#         1    0.000    0.000    0.000    0.000 base_events.py:717(is_closed)

# %%
from memory_profiler import memory_usage


nums = tuple(range(1000))
memory_profiler = memory_usage((using_range, (nums,), {}))
print("Memory usage:", memory_profiler[0])
# Out:
# Memory usage: 71.44921875
